# %% [markdown]
# # 1. Quotation
#
# a. Generate 3 best quotations for 3d printers
#
# b. Presentation for different types of 3d printers (metals as well as plastics)
#
# c. Take 10 quotations

# %% [markdown]
# # 2. Assets tool
#
# a. Create an Excel tool for assests liablities income in our house
